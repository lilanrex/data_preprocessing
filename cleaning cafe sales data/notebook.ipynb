# %%
import pandas as pd

# %%
df = pd.read_csv('dirty_cafe_sales.csv')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.dtypes # we use this to check the data types in which the columns are stored in, in this case it prints object mostly means string or mixed data type.
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
'''So in order to clean our data, we have to first convert the 'quantity' from object to int64 dtype,
then price and total spent to float64 dtype,then transaction date to datetime64[ns] '''
# Out:
# "So in order to clean our data, we have to first convert the 'quantity' from object to int64 dtype,\nthen price and total spent to float64 dtype,then transaction date to datetime64[ns] "

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce') 
#this converts the quantity column to a numeric dtype(int or float), and the coerce simply means if it encounters 
#something it can't convert, it should make it NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 625.1+ KB

# %%
df.head()
# Out:
#   Transaction ID    Item  Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee       2.0            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake       4.0            3.0        12.0            Cash
# 2    TXN_4271903  Cookie       4.0            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad       2.0            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee       2.0            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df['Price Per Unit']  = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0         4.0
# 1    TXN_4977031    Cake       4.0             3.0        12.0
# 2    TXN_4271903  Cookie       4.0             1.0       ERROR
# 3    TXN_7034554   Salad       2.0             5.0        10.0
# 4    TXN_3160411  Coffee       2.0             2.0         4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors= 'coerce')
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          NaN
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors ='coerce')
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          NaN
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9498 non-null   float64
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9540 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 625.1+ KB

# %%
'''so we have changed the dtype to numeric type
now we have to sort the unknowns in item, payment method and location'''
import numpy as np
columns_with_unknown = ['Item', 'Payment Method', 'Location']
for col in columns_with_unknown:
    if col in df.columns:
        unknown_count = df[col][df[col] == 'UNKNOWN'].count()
        if unknown_count > 0:
            df[col] = df[col].replace('UNKNOWN', np.nan)
        else:
            print('zero unknowns found')

df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          NaN
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3             NaN       NaN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
'''now that we've made corrections to the dtypes and changed all unknowns and type coercions to NaN, we need to 
inspect the NaN more'''

print(df.isnull().sum())
# Out:
# Transaction ID         0
# Item                 677
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      2872
# Location            3603
# Transaction Date     460
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9323 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9498 non-null   float64
#  5   Payment Method    7128 non-null   object
#  6   Location          6397 non-null   object
#  7   Transaction Date  9540 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 625.1+ KB

# %%
'''since we don't have data to fill in the NaNs we have to simply drop it '''
df.isna().sum()
# Out:
# Transaction ID         0
# Item                 677
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      2872
# Location            3603
# Transaction Date     460
# dtype: int64

# %%
new_df = df.dropna()

# %%
new_df.isna().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
new_df.head()
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 4   Digital Wallet  In-store       2023-06-11
# 10            Cash  Takeaway       2023-11-07
# 12            Cash  In-store       2023-05-03

# %%
new_df.to_csv('cleaned_data', index=  False)
new_df.to_excel('cleaned.xlsx', index= False)
